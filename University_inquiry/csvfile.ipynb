# %%
import csv
csvFile = open("基本情况.csv", "r")
reader = csv.reader(csvFile)
for item in reader:
    print(item)
# Out:
# ['年份', '院校名称', '统计类型', '数量（个）', '更新时间']
# ['2015', '中山大学                      ', '毕业生数', '7486', '2016/12/16 13:40']
# ['2015', '华南理工大学                  ', '毕业生数', '5793', '2016/12/16 13:40']
# ['2015', '暨南大学                      ', '毕业生数', '4174', '2016/12/16 13:40']
# ['2015', '华南农业大学                  ', '毕业生数', '9227', '2016/12/16 13:40']
# ['2015', '南方医科大学                  ', '毕业生数', '3466', '2016/12/16 13:40']
# ['2015', '广州中医药大学                ', '毕业生数', '3290', '2016/12/16 13:40']
# ['2015', '华南师范大学                  ', '毕业生数', '6966', '2016/12/16 13:40']
# ['2015', '广东工业大学                  ', '毕业生数', '10581', '2016/12/16 13:40']
# ['2015', '广东外语外贸大学              ', '毕业生数', '4966', '2016/12/16 13:40']
# ['2015', '广东财经大学                    ', '毕业生数', '5680', '2016/12/16 13:40']
# ['2015', '仲恺农业工程学院              ', '毕业生数', '4020', '2016/12/16 13:40']
# ['2015', '广东药学院                    ', '毕业生数', '5048', '2016/12/16 13:40']
# ...
